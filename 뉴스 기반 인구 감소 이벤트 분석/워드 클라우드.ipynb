# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
df1 = pd.read_excel('data/키워드/2009년 불황 키워드 기사 리스트.xlsx')
df2 = pd.read_excel('data/키워드/2010년 불황 키워드 기사 리스트.xlsx')
df3 = pd.read_excel('data/키워드/2011년 불황 키워드 기사 리스트.xlsx')
df4 = pd.read_excel('data/키워드/2009년 산업 키워드 기사 리스트.xlsx')
df5 = pd.read_excel('data/키워드/2010년 산업 키워드 기사 리스트.xlsx')
df6 = pd.read_excel('data/키워드/2011년 산업 키워드 기사 리스트.xlsx')
# Out:
# C:\Users\Bigdata\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df7 = pd.read_excel('data/키워드/2009년 폐업 키워드 기사 리스트.xlsx')
df8 = pd.read_excel('data/키워드/2010년 폐업 키워드 기사 리스트.xlsx')
df9 = pd.read_excel('data/키워드/2011년 폐업 키워드 기사 리스트.xlsx')
df10 = pd.read_excel('data/키워드/2009년 조선 키워드 기사 리스트.xlsx')
df11 = pd.read_excel('data/키워드/2010년 조선 키워드 기사 리스트.xlsx')
df12 = pd.read_excel('data/키워드/2011년 조선 키워드 기사 리스트.xlsx')
# Out:
# C:\Users\Bigdata\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
a = []
for i in range(len(df1)):
    s1 = df1['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

# %%
nouns = a
count = Counter(nouns)
tags = count.most_common(60)
tags[:60]
# Out:
# [('불황', 4173),
#  ('지역', 3516),
#  ('기업', 3159),
#  ('업체', 2854),
#  ('시장', 2777),
#  ('경기', 2747),
#  ('매출', 2438),
#  ('경제', 2150),
#  ('증가', 1968),
#  ('세계', 1963),
#  ('판매', 1872),
#  ('수출', 1839),
#  ('지원', 1791),
#  ('위기', 1759),
#  ('감소', 1695),
#  ('가격', 1689),
#  ('사업', 1633),
#  ('생산', 1557),
#  ('제품', 1556),
#  ('울산', 1514),
#  ('회사', 1497),
#  ('자동차', 1446),
#  ('전망', 1423),
#  ('관계자', 1376),
#  ('대표', 1338),
#  ('중소기업', 1324),
#  ('투자', 1317),
#  ('상품', 1300),
#  ('달러', 1294),
#  ('산업', 1292),
#  ('대비', 1291),
#  ('기록', 1243),
#  ('정부', 1233),
#  ('정도', 1204),
#  ('상황', 1195),
#  ('부산', 1194),
#  ('시작', 1103),
#  ('고객', 1099),
#  ('공장', 1083),
#  ('계획', 1078),
#  ('성장', 1067),
#  ('미국', 1026),
#  ('경영', 1012),
#  ('전년', 992),
#  ('예상', 959),
#  ('침체', 942),
#  ('글로벌', 936),
#  ('실적', 932),
#  ('인기', 922),
#  ('규모', 921),
#  ('기간', 899),
#  ('조선', 898),
#  ('일자리', 887),
#  ('백화점', 882),
#  ('취업', 881),
#  ('브랜드', 880),
#  ('금융', 865),
#  ('확대', 852),
#  ('최대', 849),
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)

# %%
a = []
for i in range(len(df2)):
    s1 = df2['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
tags[:60]
# Out:
# [('지역', 1159),
#  ('불황', 982),
#  ('기업', 923),
#  ('시장', 860),
#  ('업체', 783),
#  ('경기', 773),
#  ('증가', 760),
#  ('경제', 724),
#  ('수출', 703),
#  ('가격', 681),
#  ('달러', 646),
#  ('사업', 632),
#  ('세계', 612),
#  ('조선', 567),
#  ('부산', 558),
#  ('수주', 555),
#  ('전망', 494),
#  ('선박', 489),
#  ('미국', 447),
#  ('투자', 441),
#  ('위기', 430),
#  ('기록', 429),
#  ('산업', 423),
#  ('지원', 420),
#  ('회사', 409),
#  ('아파트', 407),
#  ('성장', 393),
#  ('매출', 388),
#  ('부동산', 378),
#  ('정부', 378),
#  ('대비', 375),
#  ('생산', 374),
#  ('감소', 370),
#  ('울산', 367),
#  ('금융', 365),
#  ('회복', 364),
#  ('정도', 358),
#  ('제품', 350),
#  ('글로벌', 341),
#  ('상승', 338),
#  ('중국', 332),
#  ('중소기업', 321),
#  ('계획', 318),
#  ('회장', 316),
#  ('실적', 314),
#  ('자동차', 312),
#  ('전년', 305),
#  ('대표', 304),
#  ('규모', 295),
#  ('일본', 294),
#  ('예상', 293),
#  ('상황', 288),
#  ('관계자', 286),
#  ('수준', 277),
#  ('조사', 269),
#  ('신규', 264),
#  ('해외', 264),
#  ('판매', 255),
#  ('분양', 254),
#  ('경쟁력', 251)]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)

# %%
a = []
for i in range(len(df3)):
    s1 = df3['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
tags[:60]
# Out:
# [('지역', 863),
#  ('불황', 651),
#  ('경기', 614),
#  ('기업', 605),
#  ('시장', 578),
#  ('경제', 563),
#  ('증가', 547),
#  ('전망', 504),
#  ('업체', 465),
#  ('매출', 449),
#  ('가격', 434),
#  ('투자', 427),
#  ('수출', 382),
#  ('산업', 379),
#  ('위기', 369),
#  ('사업', 363),
#  ('상승', 349),
#  ('기록', 346),
#  ('대구', 345),
#  ('정부', 338),
#  ('내년', 336),
#  ('성장', 325),
#  ('세계', 314),
#  ('울산', 311),
#  ('달러', 302),
#  ('확대', 296),
#  ('아파트', 287),
#  ('수준', 285),
#  ('대비', 282),
#  ('부동산', 282),
#  ('감소', 281),
#  ('실적', 279),
#  ('상황', 278),
#  ('판매', 263),
#  ('부산', 263),
#  ('글로벌', 258),
#  ('금융', 243),
#  ('회사', 242),
#  ('창업', 241),
#  ('중소기업', 235),
#  ('생산', 232),
#  ('예상', 231),
#  ('관계자', 231),
#  ('규모', 230),
#  ('지원', 230),
#  ('정도', 230),
#  ('상품', 226),
#  ('중국', 226),
#  ('물가', 225),
#  ('시작', 225),
#  ('미국', 223),
#  ('업계', 221),
#  ('대표', 220),
#  ('건설', 217),
#  ('제품', 213),
#  ('수요', 206),
#  ('기준', 203),
#  ('주택', 200),
#  ('백화점', 199),
#  ('일본', 197)]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)

# %%
a = []
for i in range(len(df4)):
    s1 = df4['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
print(tags[:60])

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# [('산업', 18303), ('기업', 13742), ('지역', 13489), ('사업', 9849), ('지원', 9010), ('생산', 8680), ('업체', 8387), ('경제', 8330), ('시장', 7486), ('정부', 7332), ('수출', 7317), ('자동차', 6987), ('성장', 6686), ('세계', 6617), ('에너지', 6412), ('투자', 6140), ('계획', 5118), ('분야', 4982), ('울산', 4969), ('추진', 4885), ('중소기업', 4609), ('제품', 4395), ('공장', 4272), ('달러', 4248), ('대표', 4100), ('발전', 3966), ('전망', 3955), ('확대', 3917), ('부품', 3803), ('녹색', 3795), ('부산', 3714), ('경기', 3654), ('증가', 3638), ('규모', 3600), ('경쟁력', 3551), ('회사', 3529), ('미국', 3493), ('위기', 3440), ('육성', 3343), ('대구', 3291), ('한국', 3173), ('단지', 3132), ('글로벌', 3085), ('중국', 3027), ('강화', 3016), ('일본', 2979), ('해외', 2975), ('대상', 2946), ('정책', 2942), ('금융', 2900), ('조성', 2900), ('구축', 2889), ('환경', 2859), ('감소', 2833), ('수준', 2794), ('확보', 2753), ('회장', 2752), ('대비', 2722), ('예정', 2696), ('관계자', 2695)]

# %%
a = []
for i in range(len(df5)):
    s1 = df5['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
print(tags[:60])

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# [('산업', 16966), ('기업', 13904), ('지역', 13624), ('사업', 10565), ('지원', 9435), ('업체', 8111), ('생산', 7861), ('시장', 7612), ('수출', 6524), ('경제', 6516), ('세계', 5825), ('투자', 5803), ('자동차', 5625), ('성장', 5335), ('중소기업', 5257), ('계획', 5200), ('정부', 5045), ('분야', 5036), ('추진', 4514), ('에너지', 4426), ('울산', 4332), ('제품', 4318), ('증가', 4241), ('달러', 3945), ('대표', 3799), ('공장', 3758), ('부산', 3726), ('확대', 3705), ('육성', 3596), ('규모', 3585), ('발전', 3496), ('경쟁력', 3409), ('전망', 3405), ('중국', 3297), ('부품', 3294), ('미국', 3255), ('대구', 3140), ('회사', 3115), ('단지', 3065), ('글로벌', 3053), ('해외', 2933), ('인력', 2917), ('한국', 2858), ('강화', 2840), ('대상', 2836), ('조성', 2777), ('예정', 2774), ('구축', 2689), ('관계자', 2680), ('일본', 2562), ('소재', 2545), ('선정', 2498), ('정책', 2493), ('마련', 2486), ('섬유', 2416), ('공급', 2407), ('가능', 2403), ('대학', 2386), ('수준', 2377), ('확보', 2374)]

# %%
a = []
for i in range(len(df6)):
    s1 = df6['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
print(tags[:60])

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# [('산업', 14841), ('지역', 12266), ('기업', 11619), ('사업', 7698), ('지원', 7560), ('수출', 6291), ('업체', 6279), ('생산', 6265), ('시장', 6130), ('경제', 5393), ('울산', 4826), ('세계', 4803), ('투자', 4589), ('자동차', 4530), ('성장', 4240), ('중소기업', 4193), ('달러', 4189), ('분야', 4057), ('정부', 4023), ('계획', 3971), ('증가', 3736), ('대표', 3683), ('에너지', 3577), ('추진', 3543), ('일본', 3539), ('공장', 3456), ('제품', 3378), ('발전', 3311), ('전망', 3292), ('부품', 3291), ('부산', 3256), ('확대', 3202), ('규모', 3088), ('대구', 3069), ('회사', 3043), ('미국', 2966), ('섬유', 2800), ('경쟁력', 2785), ('단지', 2764), ('FTA', 2692), ('가격', 2671), ('중국', 2658), ('육성', 2600), ('강화', 2415), ('한국', 2404), ('글로벌', 2388), ('대상', 2363), ('유치', 2359), ('해외', 2357), ('선정', 2315), ('관계자', 2309), ('전국', 2277), ('대학', 2273), ('구축', 2261), ('회장', 2179), ('우리나라', 2176), ('교육', 2162), ('예정', 2160), ('금융', 2147), ('운영', 2137)]

# %%
a = []
for i in range(len(df7)):
    s1 = df7['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
print(tags[:60])

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# [('지원', 1270), ('폐업', 924), ('지역', 766), ('업체', 600), ('사업', 552), ('정부', 501), ('기업', 481), ('자영업자', 474), ('창업', 443), ('일자리', 434), ('대상', 419), ('대출', 401), ('자금', 401), ('중소기업', 366), ('확대', 351), ('경제', 348), ('증가', 340), ('경기', 332), ('소상공인', 330), ('운영', 314), ('SSM', 304), ('감소', 291), ('보증', 277), ('고용', 265), ('계획', 265), ('시장', 261), ('소득', 258), ('신청', 258), ('정도', 257), ('규모', 253), ('조사', 251), ('위기', 245), ('가구', 240), ('영세', 227), ('부산', 225), ('관계자', 222), ('마련', 221), ('근로자', 216), ('금융', 214), ('입점', 214), ('상황', 212), ('대형', 207), ('공제', 203), ('회사', 200), ('신용', 199), ('가입', 197), ('가격', 194), ('판매', 191), ('기준', 191), ('연장', 187), ('중소', 186), ('전국', 185), ('기간', 182), ('수준', 182), ('영업', 182), ('매출', 181), ('여성', 179), ('대책', 179), ('1년', 176), ('센터', 176)]

# %%
a = []
for i in range(len(df8)):
    s1 = df8['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
print(tags[:60])

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# [('폐업', 547), ('업체', 545), ('지원', 377), ('지역', 341), ('기업', 323), ('사업', 302), ('회사', 261), ('가입', 255), ('창업', 224), ('소비자', 223), ('공제', 212), ('중소기업', 199), ('피해', 199), ('서비스', 181), ('증가', 180), ('대상', 167), ('부산', 159), ('환급', 155), ('상조', 155), ('고용', 153), ('계약', 151), ('자영업자', 150), ('자금', 150), ('조사', 150), ('정부', 148), ('제도', 146), ('경제', 146), ('시장', 140), ('고객', 137), ('요구', 136), ('관계자', 129), ('산업', 129), ('판매', 127), ('확대', 126), ('지급', 125), ('가격', 120), ('기간', 118), ('운영', 118), ('제공', 115), ('매출', 115), ('마산', 115), ('투자', 114), ('대표', 113), ('경영', 109), ('공장', 109), ('가능', 109), ('금액', 108), ('미만', 108), ('해지', 108), ('시작', 107), ('발생', 106), ('감소', 106), ('일자리', 104), ('사실', 104), ('사용', 103), ('대형', 103), ('점포', 103), ('전국', 102), ('기준', 101), ('상황', 101)]

# %%
a = []
for i in range(len(df9)):
    s1 = df9['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
print(tags[:60])

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# [('업체', 538), ('지역', 489), ('폐업', 475), ('창업', 341), ('지원', 312), ('사업', 270), ('가격', 241), ('피해', 216), ('주유소', 210), ('기업', 205), ('경제', 204), ('자영업자', 200), ('울산', 200), ('시장', 191), ('대구', 188), ('정부', 187), ('운영', 169), ('소비자', 157), ('요구', 155), ('전국', 148), ('점포', 146), ('중소기업', 145), ('관계자', 143), ('수수료', 140), ('확대', 139), ('증가', 134), ('음식점', 133), ('이마트', 131), ('자금', 128), ('공제', 126), ('대책', 124), ('대상', 124), ('카드', 123), ('정도', 122), ('업종', 121), ('판매', 119), ('제도', 119), ('기준', 119), ('영업', 118), ('감소', 118), ('대형', 115), ('등록', 115), ('매출', 113), ('계획', 112), ('발생', 111), ('규모', 109), ('상황', 108), ('유통', 108), ('상권', 108), ('상품', 103), ('경쟁', 102), ('고객', 101), ('위기', 100), ('공장', 100), ('영세', 100), ('소상공인', 100), ('FTA', 99), ('조사', 99), ('식당', 98), ('중소', 98)]

# %%
a = []
for i in range(len(df10)):
    s1 = df10['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
print(tags[:60])

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# [('조선', 4159), ('기업', 3241), ('산업', 2763), ('지역', 2757), ('세계', 2468), ('업체', 2460), ('선박', 2430), ('수출', 2394), ('시장', 2221), ('생산', 2206), ('사업', 1865), ('수주', 1826), ('자동차', 1774), ('부산', 1716), ('울산', 1687), ('전망', 1682), ('경제', 1670), ('달러', 1653), ('지원', 1601), ('경기', 1545), ('투자', 1424), ('STX', 1370), ('성장', 1342), ('정부', 1341), ('현대중공업', 1294), ('회사', 1275), ('분야', 1234), ('증가', 1227), ('계획', 1210), ('규모', 1195), ('에너지', 1137), ('중소기업', 1097), ('기록', 1079), ('위기', 1043), ('예상', 1029), ('매출', 1020), ('경남', 1005), ('대표', 988), ('감소', 983), ('금융', 973), ('회장', 967), ('대비', 961), ('건조', 959), ('발전', 952), ('중국', 951), ('글로벌', 944), ('확대', 932), ('관계자', 910), ('추진', 880), ('실적', 878), ('업종', 867), ('상승', 853), ('공장', 850), ('한국', 850), ('제품', 827), ('대상', 807), ('풍력', 806), ('부품', 804), ('경쟁력', 794), ('해양', 787)]

# %%
a = []
for i in range(len(df11)):
    s1 = df11['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
print(tags[:60])

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# [('조선', 3623), ('기업', 3598), ('지역', 2924), ('업체', 2790), ('산업', 2751), ('사업', 2326), ('수출', 1986), ('시장', 1952), ('부산', 1893), ('지원', 1877), ('세계', 1846), ('수주', 1793), ('달러', 1759), ('선박', 1638), ('자동차', 1564), ('울산', 1449), ('생산', 1442), ('경제', 1442), ('전망', 1418), ('증가', 1402), ('중소기업', 1351), ('중국', 1311), ('투자', 1310), ('분야', 1215), ('계획', 1101), ('성장', 1065), ('경기', 1051), ('현대중공업', 1035), ('업종', 1008), ('규모', 1004), ('정부', 969), ('회사', 960), ('추진', 946), ('부품', 904), ('기자재', 902), ('해양', 898), ('해외', 896), ('글로벌', 883), ('플랜트', 881), ('상승', 876), ('확대', 864), ('예상', 849), ('실적', 823), ('경쟁력', 814), ('기록', 813), ('금융', 796), ('매출', 778), ('대표', 766), ('가격', 760), ('관계자', 758), ('제품', 746), ('에너지', 744), ('대비', 701), ('한국', 688), ('발전', 683), ('협력', 669), ('대상', 667), ('조선소', 666), ('건설', 665), ('위기', 642)]

# %%
a = []
for i in range(len(df12)):
    s1 = df12['키워드'].iloc[i]
    s1 = s1.split(',')
    a.extend(s1)

nouns = a
count = Counter(nouns)
tags = count.most_common(60)
print(tags[:60])

# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font_path = '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf'

wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# [('조선', 2631), ('산업', 2457), ('기업', 2454), ('지역', 2298), ('수출', 1871), ('울산', 1710), ('세계', 1658), ('달러', 1653), ('업체', 1638), ('선박', 1595), ('자동차', 1535), ('시장', 1461), ('부산', 1395), ('전망', 1294), ('해양', 1267), ('사업', 1254), ('경제', 1187), ('생산', 1086), ('지원', 1083), ('중국', 1082), ('수주', 1045), ('증가', 1035), ('분야', 1018), ('현대중공업', 998), ('성장', 993), ('일본', 874), ('투자', 855), ('중소기업', 847), ('상승', 840), ('업종', 797), ('부품', 771), ('기록', 763), ('플랜트', 733), ('가격', 731), ('예상', 719), ('계획', 718), ('회사', 707), ('경기', 690), ('규모', 689), ('대표', 669), ('확대', 662), ('미국', 650), ('기자재', 642), ('관계자', 635), ('에너지', 630), ('매출', 630), ('정부', 628), ('글로벌', 621), ('경남', 621), ('대비', 612), ('해외', 602), ('발전', 592), ('실적', 592), ('우리나라', 590), ('추진', 590), ('회장', 587), ('제품', 579), ('금융', 567), ('내년', 554), ('한국', 553)]
